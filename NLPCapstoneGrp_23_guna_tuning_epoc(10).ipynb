# %% [markdown]
# <a href="https://colab.research.google.com/github/MaddyBasu/CapstoneAIML/blob/main/NLPCapstoneGrp_23_guna_tuning_epoc(10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NATURAL LANGUAGE PROCESSING: MACHINE LEARNING (ENGLISH - GERMAN TRANSLATOR)**
#
# **Capstone Project - Authors:** Bhagawan Das Armani, Gunasekaran Venkatesan, Madhuman Basu, Sanjay R, Vinayak Hampiholi, Vipin Nair

# %% [markdown]
# # **Introduction and Overview**

# %% [markdown]
# **1. Introduction**

# %% [markdown]
# In today’s interconnected world, seamless communication across different languages is essential. **Machine Translation (MT)** plays a crucial role in breaking language barriers by enabling the automated translation of text from one language to another without human intervention.
#
# This project focuses on building a **Neural Machine Translation (NMT)** model for **English-to-German and German-to-English** translation using advanced deep learning techniques. Leveraging datasets from the **ACL2014 Ninth Workshop on Statistical Machine Translation**, we will explore various model architectures, including **Recurrent Neural Networks (RNNs), Long Short-Term Memory Networks (LSTMs), and Bidirectional LSTMs** to enhance translation accuracy.
#
# The project is structured into **two key milestones:**
#
# * **Milestone 1:** Data preprocessing, exploratory analysis, and dataset preparation.
# * **Milestone 2:** Model building, training, evaluation, and selection of the best-performing model.
#
# Through this project, we aim to explore state-of-the-art machine translation techniques, evaluate different deep learning models, and improve translation accuracy using advanced **NLP preprocessing methods**.

# %% [markdown]
# **2. Project Objectives**
#
# The primary objectives of the project are:
#
# **Milestone 1: Data Preparation & Preprocessing**
#
# ✅ Import, merge, and preprocess **three bilingual datasets** to ensure high-quality input for training.
#
# ✅ Perform **data cleansing** to handle missing values, duplicates, and inconsistencies.
#
# ✅ Apply **NLP preprocessing** (tokenization, lowercasing, sentence-length filtering) to optimize the dataset for deep learning models.
#
# ✅ Summarize findings in an **Interim Report** outlining key insights from the dataset and preprocessing steps.
#
# **Milestone 2: Model Development & Optimization**
#
# ✅ **Train and evaluate different deep learning architectures** for translation:
#
# * **Basic RNN & LSTM mode**l with word embeddings.
# * **Bidirectional RNN & LSTM model** for improved context understanding.
#
# (Optional) **Encoder-Decoder model** to explore sequence-to-sequence translation.
#
# ✅ **Compare model performance** and select the best approach.
#
# ✅ Serialize and save the **best-performing model** (Pickle).
#
# ✅ Document all findings, methodologies, and results in a **Final Report**.

# %% [markdown]
# **3. Data Overview**
#
# The datasets used in this project come from the **ACL2014 Statistical Machine Translation Workshop** and contain English-German parallel sentences. These datasets are critical in training supervised learning-based **Neural Machine Translation (NMT)** models.
#
# ### Dataset Overview
# | Dataset               | Description                                  | Size       |
# |-----------------------|----------------------------------------------|------------|
# | **Europarl v7**       | Formal, structured parliamentary proceedings | Large      |
# | **Common Crawl Corpus** | Informal, diverse text from web crawls      | Very Large |
# | **News Commentary**   | Journalistic and news-related bilingual texts | Medium     |
#
#
# Each dataset consists of sentence pairs in English and German, making them ideal for sequence-to-sequence translation models.

# %% [markdown]
# **4. Problem Statement**
#
# The primary challenge in machine translation is accurately capturing **linguistic structures**, context, and semantics while ensuring fluency and grammatical correctness. Unlike simple word-for-word translation, an effective model must account for:
#
#
# * **Idiomatic expressions and contextual meanings.**
# * **Sentence structure variations between English and German.**
# * **Long-sequence dependencies that may lead to information loss.**
# * **Optimization of deep learning models for high-quality translation.**
#
# This project will address these challenges by leveraging **deep learning models (RNNs, LSTMs, and Encoder-Decoder architectures)**, **preprocessing technique**s, and **performance evaluation metrics (BLEU Score)**.

# %% [markdown]
# **5. Milestone 1: Data Processing & Preprocessing**
#
# This phase ensures that the dataset is clean, structured, and optimized for deep learning model training.
#
# 🔹 **Steps Involved:**
#
# ✅ **Step 1:** Import and merge the three datasets.
#
# ✅ **Step 2:** Perform data cleansing – remove duplicates, fix missing values, and normalize text.
#
# ✅ **Step 3:** Apply NLP preprocessing – tokenization, stopword removal, lowercasing, and sentence-length filtering.
#
# ✅ **Step 4:** Prepare the dataset for RNN & LSTM models by structuring text into sequences.
#
# ✅ **Step 5:** Submit an Interim Report summarizing findings and preprocessing steps.

# %% [markdown]
# **6. Milestone 2: Model Building & Evaluation**
#
# This phase focuses on **developing, training, and evaluating different deep learning models**.
#
# 🔹 **Steps Involved:**
#
# ✅ **Step 1:** Train and evaluate a basic RNN & LSTM model with word embeddings.
#
# ✅ **Step 2:** Train and test a Bidirectional RNN & LSTM model for improved context understanding.
#
# ✅ **Step 3:** (Optional) Experiment with an Encoder-Decoder model for sequence-to-sequence translation.
#
# ✅ **Step 4:** Select the best-performing model, serialize (pickle) it, and save for future use.
#
# ✅ **Step 5:** Prepare and submit the Final Report, including results, comparisons, and insights.

# %% [markdown]
# **7. Evaluation Metrics**
#
# The performance of each model will be evaluated using:
#
# 📌 ***BLEU Score ***– A widely used metric for assessing translation quality by comparing generated translations to human references.
#
# 📌 **Perplexity Score** – Measures how well a probabilistic model predicts a sample.
#
# 📌 **Manual Evaluation** – Observing sentence structure and fluency in translations.

# %% [markdown]
# **8. Expected Outcomes**
#
# By the end of this project, we aim to:
#
# ✔ **Develop a robust and scalable Neural Machine Translation model.**
#
# ✔ **Optimize translation accuracy using advanced deep learning techniques.**
#
# ✔ **Compare different architectures (RNN, LSTM, Encoder-Decoder) to identify the best approach.**
#
# ✔ **Achieve a high BLEU Score, indicating high translation accuracy.**
#
# ✔ **Deliver a complete Jupyter Notebook and Final Report documenting the process and findings.**

# %% [markdown]
# **9. Final Submission Checklist**
#
# 📌 **Interim Report **(Milestone 1: Data Preprocessing & Findings).
#
# 📌 **Final Report** (Milestone 2: Model Training, Evaluation & Results).
#
# 📌 **Notebook** with all steps, models, and code implementations.
#
# 📌 **Pickled Best Model** for future reuse.

# %% [markdown]
# **Code to Import Datasets into Google Colab**

# %%
# Import warnings library to make warnings not displayed
import warnings

# Set the warning filters to ignore the warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **1. Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. Import Necessary Libraries**

# %%
# Import the required libraries
import IPython
import numpy
import pandas as pd
from IPython.display import display, Markdown

# Collect version details
ipython_version = IPython.__version__
numpy_version = numpy.__version__
pandas_version = pd.__version__

# Display all observations in a single line
display(Markdown(f"**Observations:** IPython Version: {ipython_version}, numpy Version: {numpy_version}, pandas Version: {pandas_version}"))
# Out:
# **Observations:** IPython Version: 7.34.0, numpy Version: 2.0.2, pandas Version: 2.2.2

# %% [markdown]
# # **PROJECT TASK: MILESTONE 1**

# %% [markdown]
# **Step 1: Import and merge the three datasets.**

# %% [markdown]
# **Load and Verify Datasets**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from IPython.display import display, Markdown

# Function to load parallel datasets with error handling
def load_parallel_data(filepath_de, filepath_en, dataset_name):
    """Loads English-German parallel datasets and handles line mismatches."""

    try:
        # Read German text
        with open(filepath_de, "r", encoding="utf-8") as de_file:
            de_lines = de_file.readlines()

        # Read English text
        with open(filepath_en, "r", encoding="utf-8") as en_file:
            en_lines = en_file.readlines()

        # Find the minimum number of lines
        min_length = min(len(de_lines), len(en_lines))

        # Truncate the longer file to match the shorter one
        de_lines = de_lines[:min_length]
        en_lines = en_lines[:min_length]

        # Create DataFrame
        df = pd.DataFrame({"German": de_lines, "English": en_lines})

        # Display confirmation
        display(Markdown(f"### Successfully Loaded {dataset_name} Dataset"))
        display(Markdown(f"Total Sentence Pairs (After Fixing Mismatch): {len(df)}"))

        # Show sample data
        display(df.head())

        return df

    except Exception as e:
        display(Markdown(f"Error loading {dataset_name}: {str(e)}"))
        return None

# %% [markdown]
# **Load All Three Datasets**

# %%
# Define file paths

# Europarl Dataset
europarl_de_path = "/content/drive/MyDrive/MachineTranslation/DataSet/europarl-v7_de_en.txt"
europarl_en_path = "/content/drive/MyDrive/MachineTranslation/DataSet/europarl-v7_en_de.txt"

# CommonCrawl Dataset
commoncrawl_de_path = "/content/drive/MyDrive/MachineTranslation/DataSet/commoncrawl_de_en.txt"
commoncrawl_en_path = "/content/drive/MyDrive/MachineTranslation/DataSet/commoncrawl_en_de.txt"

# NewsCommentary Dataset
newscommentary_de_path = "/content/drive/MyDrive/MachineTranslation/DataSet/news-commentary-v9_de_en.txt"
newscommentary_en_path = "/content/drive/MyDrive/MachineTranslation/DataSet/news-commentary-v9_en_de.txt"

# Load datasets
europarl_df = load_parallel_data(europarl_de_path, europarl_en_path, "Europarl")
commoncrawl_df = load_parallel_data(commoncrawl_de_path, commoncrawl_en_path, "CommonCrawl")
newscommentary_df = load_parallel_data(newscommentary_de_path, newscommentary_en_path, "NewsCommentary")
# Out:
# ### Successfully Loaded Europarl Dataset
# Total Sentence Pairs (After Fixing Mismatch): 1920209
#                                               German  \
# 0               Wiederaufnahme der Sitzungsperiode\n
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                              English
# 0                        Resumption of the session\n
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...
# ### Successfully Loaded CommonCrawl Dataset
# Total Sentence Pairs (After Fixing Mismatch): 2399123
#                                               German  \
# 0  iron cement ist eine gebrauchs-fertige Paste, ...
# 1  Nach der Aushärtung schützt iron cement die Ko...
# 2  feuerfester Reparaturkitt für Feuerungsanlagen...
# 3     Der Bau und die Reparatur der Autostraßen...\n
# 4  die Mitteilungen sollen den geschäftlichen kom...
#
#                                              English
# 0  iron cement is a ready for use paste which is ...
# 1  iron cement protects the ingot against the hot...
# 2  a fire restant repair cement for fire places, ...
# 3       Construction and repair of highways and...\n
# 4    An announcement must be commercial character.\n
# ### Successfully Loaded NewsCommentary Dataset
# Total Sentence Pairs (After Fixing Mismatch): 201854
#                                               German  \
# 0                   Steigt Gold auf 10.000 Dollar?\n
# 1  SAN FRANCISCO – Es war noch nie leicht, ein ra...
# 2  In letzter Zeit allerdings ist dies schwierige...
# 3  Erst letzten Dezember verfassten meine Kollege...
# 4                Und es kam, wie es kommen musste.\n
#
#                                              English
# 0                                    $10,000 Gold?\n
# 1  SAN FRANCISCO – It has never been easy to have...
# 2  Lately, with gold prices up more than 300% ove...
# 3  Just last December, fellow economists Martin F...
# 4                            Wouldn’t you know it?\n

# %% [markdown]
# **Compare Row Counts and Visualize Dataset Sizes**

# %%
import numpy as np

# Function to check dataset integrity
def check_dataset_integrity(df, dataset_name):
    """Compares the number of German and English sentences in a dataset and visualizes the dataset size."""

    if df is not None:
        num_de = df["German"].shape[0]
        num_en = df["English"].shape[0]

        display(Markdown(f"### Integrity Check for {dataset_name} Dataset"))
        display(Markdown(f"- German Sentences: {num_de}"))
        display(Markdown(f"- English Sentences: {num_en}"))

        if num_de == num_en:
            display(Markdown("- The dataset is aligned correctly."))
        else:
            display(Markdown("- Mismatch detected: The number of German and English sentences are different."))

        # Visualization: Bar Chart for Dataset Sizes
        plt.figure(figsize=(5, 3))
        plt.bar(["German", "English"], [num_de, num_en], color=['blue', 'red'])
        plt.xlabel("Language")
        plt.ylabel("Sentence Count")
        plt.title(f"Comparison of German & English Sentences in {dataset_name}")
        plt.show()

# Run checks on all datasets
check_dataset_integrity(europarl_df, "Europarl")
check_dataset_integrity(commoncrawl_df, "CommonCrawl")
check_dataset_integrity(newscommentary_df, "NewsCommentary")
# Out:
# ### Integrity Check for Europarl Dataset
# - German Sentences: 1920209
# - English Sentences: 1920209
# - The dataset is aligned correctly.
# ### Integrity Check for CommonCrawl Dataset
# - German Sentences: 2399123
# - English Sentences: 2399123
# - The dataset is aligned correctly.
# ### Integrity Check for NewsCommentary Dataset
# - German Sentences: 201854
# - English Sentences: 201854
# - The dataset is aligned correctly.

# %% [markdown]
# **Merge All Three Datasets and Visualize Distribution**

# %%
# Function to merge multiple datasets
def merge_datasets(dfs, dataset_name):
    """Merges multiple translation datasets and removes duplicates."""

    merged_df = pd.concat(dfs, ignore_index=True).drop_duplicates()

    display(Markdown(f"### Merged Dataset: {dataset_name}"))
    display(Markdown(f"Total Translation Pairs After Merging: {len(merged_df)}"))
    display(merged_df.head())

    # Visualization: Pie Chart for Sentence Contribution
    dataset_sizes = [len(df) for df in dfs]
    dataset_labels = ["Europarl", "CommonCrawl", "NewsCommentary"]

    plt.figure(figsize=(5, 5))
    plt.pie(dataset_sizes, labels=dataset_labels, autopct="%1.1f%%", colors=["blue", "red", "green"])
    plt.title(f"Sentence Contribution by Dataset in {dataset_name}")
    plt.show()

    return merged_df

# Merge Europarl, CommonCrawl, and NewsCommentary datasets
translation_dataset = merge_datasets([europarl_df, commoncrawl_df, newscommentary_df], "Europarl + CommonCrawl + NewsCommentary")
# Out:
# ### Merged Dataset: Europarl + CommonCrawl + NewsCommentary
# Total Translation Pairs After Merging: 4476170
#                                               German  \
# 0               Wiederaufnahme der Sitzungsperiode\n
# 1  Ich erkläre die am Freitag, dem 17. Dezember u...
# 2  Wie Sie feststellen konnten, ist der gefürchte...
# 3  Im Parlament besteht der Wunsch nach einer Aus...
# 4  Heute möchte ich Sie bitten - das ist auch der...
#
#                                              English
# 0                        Resumption of the session\n
# 1  I declare resumed the session of the European ...
# 2  Although, as you will have seen, the dreaded '...
# 3  You have requested a debate on this subject in...
# 4  In the meantime, I should like to observe a mi...

# %% [markdown]
# **Optimized Unique Row Check & Word Cloud Generation**

# %%
import random

# Function to check unique rows and visualize a subset of words
def check_unique_rows(df, dataset_name, sample_size=10000):
    """Checks unique values and generates optimized word clouds using a subset of data."""

    if df is not None:
        num_de_unique = df["German"].nunique()
        num_en_unique = df["English"].nunique()

        display(Markdown(f"### Unique Row Check for {dataset_name}"))
        display(Markdown(f"- Unique German Sentences: {num_de_unique}"))
        display(Markdown(f"- Unique English Sentences: {num_en_unique}"))

        if num_de_unique == num_en_unique:
            display(Markdown("- The number of unique sentences in both columns is the same."))
        else:
            display(Markdown("- Mismatch detected: Different number of unique sentences in German and English."))

        # Reduce dataset size for visualization (take a random sample)
        sample_df = df.sample(min(sample_size, len(df)), random_state=42)

        # Generate Word Cloud for English
        plt.figure(figsize=(8, 4))
        wordcloud = WordCloud(width=800, height=400, max_words=500, background_color="white").generate(" ".join(sample_df["English"]))
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.title(f"Common Words in English Sentences ({dataset_name})")
        plt.show()

        # Generate Word Cloud for German
        plt.figure(figsize=(8, 4))
        wordcloud = WordCloud(width=800, height=400, max_words=500, background_color="white").generate(" ".join(sample_df["German"]))
        plt.imshow(wordcloud, interpolation="bilinear")
        plt.axis("off")
        plt.title(f"Common Words in German Sentences ({dataset_name})")
        plt.show()

# Run optimized unique row checks
check_unique_rows(translation_dataset, "Europarl + CommonCrawl + NewsCommentary")
# Out:
# ### Unique Row Check for Europarl + CommonCrawl + NewsCommentary
# - Unique German Sentences: 4462013
# - Unique English Sentences: 4400303
# - Mismatch detected: Different number of unique sentences in German and English.

# %% [markdown]
# **Step 2: Data cleansing.**

# %% [markdown]
# **Handle Null Values**

# %%
# Check for null values in the dataset
display(Markdown("### Handling Null Values"))

# Display total null values in the dataset
num_nulls = translation_dataset.isnull().sum().sum()
display(Markdown(f"- Total null values in dataset: {num_nulls}"))

# Remove null values
translation_dataset = translation_dataset.dropna()

# Display number of rows after removing nulls
display(Markdown(f"- Number of rows after removing null values: {len(translation_dataset)}"))
# Out:
# ### Handling Null Values
# - Total null values in dataset: 0
# - Number of rows after removing null values: 4476170

# %% [markdown]
# **Remove Duplicate Sentences**

# %%
# Check for duplicate rows
display(Markdown("### Handling Duplicate Sentences"))

# Count total duplicate rows
num_duplicates = translation_dataset.duplicated().sum()
display(Markdown(f"- Total duplicate rows in dataset: {num_duplicates}"))

# Remove duplicate rows
translation_dataset = translation_dataset.drop_duplicates()

# Display number of rows after removing duplicates
display(Markdown(f"- Number of rows after removing duplicates: {len(translation_dataset)}"))
# Out:
# ### Handling Duplicate Sentences
# - Total duplicate rows in dataset: 0
# - Number of rows after removing duplicates: 4476170

# %% [markdown]
# **Filter Short and Long Sentences + Visualization**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to filter sentences by length and visualize distribution
def sentence_length_filter(df, min_words=3, max_words=50):
    """Filters out sentences that are too short or too long and visualizes sentence length distribution."""

    df["German_length"] = df["German"].apply(lambda x: len(x.split()))
    df["English_length"] = df["English"].apply(lambda x: len(x.split()))

    # Plot sentence length distribution
    plt.figure(figsize=(8, 4))
    plt.hist([df["German_length"], df["English_length"]], bins=30, alpha=0.7, label=["German", "English"], color=['blue', 'red'])
    plt.xlabel("Number of Words")
    plt.ylabel("Sentence Count")
    plt.title("Sentence Length Distribution")
    plt.legend()
    plt.show()

    # Apply filters
    filtered_df = df[(df["German_length"] >= min_words) & (df["German_length"] <= max_words) &
                     (df["English_length"] >= min_words) & (df["English_length"] <= max_words)]

    # Display changes
    display(Markdown(f"- Sentences before filtering: {len(df)}"))
    display(Markdown(f"- Sentences after filtering: {len(filtered_df)}"))

    return filtered_df.drop(columns=["German_length", "English_length"])  # Drop helper columns

# Apply sentence length filter
translation_dataset = sentence_length_filter(translation_dataset)
# Out:
# - Sentences before filtering: 4476170
# - Sentences after filtering: 4232255

# %% [markdown]
# **Standardize Text (Lowercase, Remove Special Characters, Extra Spaces)**

# %%
import re

# Function to clean text
def clean_text(text):
    """Converts text to lowercase, removes special characters, and extra spaces."""
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"[^a-zA-ZäöüßÄÖÜéèàùçâêîôûëïüÿ.,!?'-]", " ", text)  # Keep letters and common punctuation
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# Apply text cleaning to both columns
translation_dataset["German"] = translation_dataset["German"].apply(clean_text)
translation_dataset["English"] = translation_dataset["English"].apply(clean_text)

display(Markdown("- Successfully standardized text formatting in both German and English sentences."))
# Out:
# - Successfully standardized text formatting in both German and English sentences.

# %% [markdown]
# **Faster Filtering Without Language Detection**

# %%
import numpy as np
import pandas as pd

# Reduce dataset size to 10000 rows for fast execution
sample_size = min(10000, len(translation_dataset))
translation_dataset = translation_dataset.sample(sample_size, random_state=42)

# Display summary
display(Markdown("### Fast Execution Mode: Skipping Language Detection"))
display(Markdown(f"- Dataset size reduced to {len(translation_dataset)} rows for faster execution."))
# Out:
# ### Fast Execution Mode: Skipping Language Detection
# - Dataset size reduced to 10000 rows for faster execution.

# %% [markdown]
# **Final Summary of Cleaned Dataset + Visualization**

# %%
# Ensure we are using the correct dataset
if 'filtered_df' in globals():
    translation_dataset = filtered_df  # Use the filtered dataset from Step 5

# Store dataset size at each stage
dataset_sizes = {
    "Original": len(translation_dataset),
    "After Null Removal": len(translation_dataset.dropna()),
    "After Deduplication": len(translation_dataset.drop_duplicates()),
    "After Length Filtering": len(sentence_length_filter(translation_dataset)),
    "After Language Filtering": len(filtered_df) if 'filtered_df' in globals() else len(translation_dataset)
}

# Plot dataset reduction at each step
plt.figure(figsize=(8, 5))
plt.bar(dataset_sizes.keys(), dataset_sizes.values(), color=["red", "orange", "yellow", "green", "blue"])
plt.xlabel("Cleaning Step")
plt.ylabel("Number of Sentences")
plt.title("Dataset Reduction Through Cleaning Steps")
plt.show()

# Display final dataset details
display(Markdown("### Final Cleaned Dataset Summary"))
display(Markdown(f"- Total sentences after cleansing: {len(translation_dataset)}"))
display(Markdown(f"- Sample cleaned sentences:"))
display(translation_dataset.sample(5, random_state=42))
# Out:
# - Sentences before filtering: 10000
# - Sentences after filtering: 9991
# ### Final Cleaned Dataset Summary
# - Total sentences after cleansing: 10000
# - Sample cleaned sentences:
#                                                     German  \
# 3079090  führer der revolte war joanot colom, aus felan...
# 1887334  wir vertrauen darauf, daß sich die weißrussisc...
# 1317717  dies setzt voraus, dass die angenommenen siche...
# 3304652  deswegen bemühen wir uns die grundwerte, die u...
# 3931281  todestages von adam smith am letzten wochenend...
#
#                                                    English  German_length  \
# 3079090  in the th century felanitx had inhabitants, ma...             14
# 1887334  we trust that the belorussian authorities will...             15
# 1317717  this makes it essential that the security meas...             26
# 3304652  therefore we try to share basic values which a...             16
# 3931281  the forum aims to present the latest developme...             38
#
#          English_length
# 3079090              16
# 1887334              15
# 1317717              31
# 3304652              16
# 3931281              21

# %% [markdown]
# **Step 3: NLP pre processing - Dataset suitable to be used for AIML model learning**

# %% [markdown]
# **Install Faster NLP Library (spaCy)**

# %%
# Install spaCy and download language models (only run once)
import os

# Suppress installation logs
os.system("pip install -q spacy")
os.system("python -m spacy download en_core_web_sm --quiet")
os.system("python -m spacy download de_core_news_sm --quiet")

# Install swifter quietly (hide logs)
os.system("pip install -q swifter")
# Out:
# 0

# %% [markdown]
# **Optimized NLP Preprocessing with Visualizations**

# %%
import pandas as pd
import re
import spacy
import swifter  # Ensure it's installed now
import matplotlib.pyplot as plt
import seaborn as sns

# Load spaCy models for English & German
nlp_en = spacy.load("en_core_web_sm")
nlp_de = spacy.load("de_core_news_sm")

# Reduce dataset size to 10,000 rows for fast execution
sample_size = min(10000, len(translation_dataset))
translation_dataset = translation_dataset.sample(sample_size, random_state=42)

# Function to clean and tokenize text
def preprocess_text(text, nlp):
    if not isinstance(text, str) or text.strip() == "":  # Handle empty strings
        return ""

    # Convert to lowercase
    text = text.lower()

    # Remove special characters (but keep punctuation)
    text = re.sub(r"[^\w\s.,!?'-]", " ", text)

    # Tokenize and lemmatize
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop]  # Lemmatization + Stopword Removal

    return " ".join(tokens)

# Apply preprocessing using parallel processing (`swifter`)
translation_dataset["German"] = translation_dataset["German"].swifter.apply(lambda x: preprocess_text(x, nlp_de))
translation_dataset["English"] = translation_dataset["English"].swifter.apply(lambda x: preprocess_text(x, nlp_en))

# Display sample processed data
display(Markdown("### Preprocessing Completed: Sample Data"))
display(translation_dataset.head())
# Out:
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/10000 [00:00<?, ?it/s]
# ### Preprocessing Completed: Sample Data
#                                                     German  \
# 3079090  Führer Revolte Joanot colom -- Felanitx -- Bee...
# 1887334  vertrauen -- weißrussisch Behörde weiterhin Ra...
# 1317717  setzen voraus -- Angenommen sicherheitsmaßnahm...
# 3304652  bemühen grundwert -- Unbescholtenheit Qualität...
# 3931281  Todestag Adam Smith letzter Wochenende Montag ...
#
#                                                    English  German_length  \
# 3079090  th century felanitx inhabitant , mainly farmer...             14
# 1887334  trust belorussian authority remain committed e...             15
# 1317717  make essential security measure adopt compromi...             26
# 3304652  try share basic value basis impeccability qual...             16
# 3931281  forum aim present late development indirect ta...             38
#
#          English_length
# 3079090              16
# 1887334              15
# 1317717              31
# 3304652              16
# 3931281              21

# %% [markdown]
# **Visualizations After NLP Preprocessing**

# %% [markdown]
# Word Count Distribution (Before & After Preprocessing)

# %%
# Compute word counts before & after preprocessing
translation_dataset["German_WordCount"] = translation_dataset["German"].apply(lambda x: len(x.split()))
translation_dataset["English_WordCount"] = translation_dataset["English"].apply(lambda x: len(x.split()))

# Plot distribution of word counts
plt.figure(figsize=(10, 5))
sns.histplot(translation_dataset["German_WordCount"], bins=30, color="blue", label="German", kde=True)
sns.histplot(translation_dataset["English_WordCount"], bins=30, color="red", label="English", kde=True)
plt.xlabel("Word Count per Sentence")
plt.ylabel("Number of Sentences")
plt.title("Word Count Distribution (After Preprocessing)")
plt.legend()
plt.show()

# %% [markdown]
# Most Frequent Words (Word Cloud)

# %%
from wordcloud import WordCloud

# Generate Word Cloud for German
plt.figure(figsize=(8, 4))
wordcloud_de = WordCloud(width=800, height=400, max_words=100, background_color="white").generate(" ".join(translation_dataset["German"]))
plt.imshow(wordcloud_de, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in German (After Preprocessing)")
plt.show()

# Generate Word Cloud for English
plt.figure(figsize=(8, 4))
wordcloud_en = WordCloud(width=800, height=400, max_words=100, background_color="white").generate(" ".join(translation_dataset["English"]))
plt.imshow(wordcloud_en, interpolation="bilinear")
plt.axis("off")
plt.title("Most Frequent Words in English (After Preprocessing)")
plt.show()

# %% [markdown]
# **Step 4: Design, train and test simple RNN & LSTM model**

# %% [markdown]
# **Preprocessing for Model Training**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Reduce dataset to 5,000 rows for faster execution
sample_size = min(5000, len(translation_dataset))
translation_dataset_sample = translation_dataset.sample(sample_size, random_state=42)

# Tokenize the text data
tokenizer = Tokenizer(num_words=5000)  # Limit vocabulary size to 5,000 words
tokenizer.fit_on_texts(translation_dataset_sample['German'] + translation_dataset_sample['English'])

# Convert text to sequences
de_sequences = tokenizer.texts_to_sequences(translation_dataset_sample['German'])
en_sequences = tokenizer.texts_to_sequences(translation_dataset_sample['English'])

# Pad sequences
max_sequence_length = 20  # Reduce sequence length for faster execution
de_padded = pad_sequences(de_sequences, maxlen=max_sequence_length, padding='post')
en_padded = pad_sequences(en_sequences, maxlen=max_sequence_length, padding='post')

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(de_padded, en_padded, test_size=0.2, random_state=42)

# Display dataset sizes
display(Markdown("### Data Preprocessed for Model Training"))
display(Markdown(f"- Training Set: {len(X_train)} samples"))
display(Markdown(f"- Testing Set: {len(X_test)} samples"))
# Out:
# ### Data Preprocessed for Model Training
# - Training Set: 4000 samples
# - Testing Set: 1000 samples

# %% [markdown]
# **Define & Train RNN Model (Simplified for Speed)**

# %%
# Define Simple RNN model with fewer neurons
rnn_model = Sequential([
    Embedding(input_dim=5000, output_dim=32, input_length=max_sequence_length),  # Smaller embedding layer
    SimpleRNN(32, return_sequences=True),  # Reduce neurons
    Dense(5000, activation='softmax')  # Use limited vocabulary size
])

# Compile the RNN model
rnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the RNN model (Reduced epochs and batch size for faster execution)
rnn_history = rnn_model.fit(X_train, y_train, epochs=3, batch_size=8, validation_data=(X_test, y_test))
# Out:
# Epoch 1/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 36s 59ms/step - accuracy: 0.5261 - loss: 5.5813 - val_accuracy: 0.5799 - val_loss: 3.5538
# Epoch 2/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 29s 35ms/step - accuracy: 0.5911 - loss: 3.3994 - val_accuracy: 0.5799 - val_loss: 3.5005
# Epoch 3/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 17s 34ms/step - accuracy: 0.5802 - loss: 3.4246 - val_accuracy: 0.5798 - val_loss: 3.4813

# %% [markdown]
# **Define & Train LSTM Model (Optimized for Speed)**

# %%
# Define LSTM model with fewer layers
lstm_model = Sequential([
    Embedding(input_dim=5000, output_dim=32, input_length=max_sequence_length),  # Smaller embedding layer
    LSTM(32, return_sequences=True),  # Reduce neurons
    Dense(5000, activation='softmax')  # Use limited vocabulary size
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the LSTM model (Reduced epochs and batch size for faster execution)
lstm_history = lstm_model.fit(X_train, y_train, epochs=3, batch_size=8, validation_data=(X_test, y_test))
# Out:
# Epoch 1/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 31s 54ms/step - accuracy: 0.5726 - loss: 5.4675 - val_accuracy: 0.5799 - val_loss: 3.5765
# Epoch 2/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 19s 38ms/step - accuracy: 0.5832 - loss: 3.4894 - val_accuracy: 0.5799 - val_loss: 3.5112
# Epoch 3/3
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 21s 39ms/step - accuracy: 0.5842 - loss: 3.4085 - val_accuracy: 0.5798 - val_loss: 3.5029

# %% [markdown]
# **Visualizing Training Progress**

# %% [markdown]
# **Plot Accuracy & Loss for RNN & LSTM**

# %%
# Function to plot training accuracy and loss
def plot_training(history, model_name):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Plot Accuracy
    axs[0].plot(history.history['accuracy'], label='Train Accuracy', color='blue')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
    axs[0].set_title(f'{model_name} - Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    # Plot Loss
    axs[1].plot(history.history['loss'], label='Train Loss', color='blue')
    axs[1].plot(history.history['val_loss'], label='Validation Loss', color='red')
    axs[1].set_title(f'{model_name} - Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

# Plot RNN Training Performance
plot_training(rnn_history, "Simple RNN")

# Plot LSTM Training Performance
plot_training(lstm_history, "LSTM")

# %% [markdown]
# **Model Evaluation & Exporting for Inference**

# %% [markdown]
# 1. **Evaluate Model Performance Using BLEU Score**

# %% [markdown]
# Why BLEU Score?
#
# * BLEU (Bilingual Evaluation Understudy) measures how similar the generated translations are to the actual translations.
#
# * It is commonly used in machine translation models.

# %% [markdown]
# **Convert Predictions to Text**

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Function to convert token sequences back to text
def sequences_to_texts(sequences, tokenizer):
    reverse_word_index = {value: key for key, value in tokenizer.word_index.items()}
    texts = []
    for seq in sequences:
        texts.append(" ".join([reverse_word_index.get(i, "") for i in seq if i > 0]))
    return texts

# Generate predictions using the trained RNN model
rnn_predictions = rnn_model.predict(X_test)
rnn_pred_sequences = np.argmax(rnn_predictions, axis=-1)  # Convert probabilities to word indices
rnn_translations = sequences_to_texts(rnn_pred_sequences, tokenizer)

# Generate predictions using the trained LSTM model
lstm_predictions = lstm_model.predict(X_test)
lstm_pred_sequences = np.argmax(lstm_predictions, axis=-1)  # Convert probabilities to word indices
lstm_translations = sequences_to_texts(lstm_pred_sequences, tokenizer)

# Get the actual reference translations (Ground Truth)
actual_translations = sequences_to_texts(y_test, tokenizer)

# Show sample predictions
display(Markdown("### Sample Translations"))
for i in range(5):
    display(Markdown(f"German Input: {sequences_to_texts([X_test[i]], tokenizer)[0]}"))
    display(Markdown(f"Actual Translation: {actual_translations[i]}"))
    display(Markdown(f"RNN Translation: {rnn_translations[i]}"))
    display(Markdown(f"LSTM Translation: {lstm_translations[i]}"))
    display(Markdown("---"))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# ### Sample Translations
# German Input: abkommen rein wirtschaftlich aspekt lassen
# Actual Translation: think need realise actually fear express agreement case purely trade
# RNN Translation:
# LSTM Translation:
# ---
# German Input: lassen berichterstatterin danken wichtig frage zusammenhang nah beleuchtung verdienen
# Actual Translation: wish begin thank rapporteur fellow member mrs having include important issue worth highlight context
# RNN Translation:
# LSTM Translation:
# ---
# German Input: bestimmt abgeordneter treten fall betroffen unternehmen informieren richtlinie vorsehen schön
# Actual Translation: case member like staff representative business well directive provide
# RNN Translation: president
# LSTM Translation: mr
# ---
# German Input: wichtig gebäude gesamt region china aufbauen konzern erinnern
# Actual Translation: old settlement city ground subject process inside machine
# RNN Translation:
# LSTM Translation:
# ---
# German Input: casino installieren k nnen casino jederzeit überall nutzen
# Actual Translation: simply download install play casino want want
# RNN Translation: president
# LSTM Translation:
# ---

# %% [markdown]
# **Compute BLEU Score**

# %%
# !pip install -q sacrebleu
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 6.4 MB/s eta 0:00:00

# %%
import sacrebleu
import numpy as np

# Function to compute BLEU score using sacrebleu
def calculate_bleu_sacrebleu(predicted_texts, reference_texts):
    bleu_scores = []
    for pred, ref in zip(predicted_texts, reference_texts):
        bleu = sacrebleu.sentence_bleu(pred, [ref]).score  # Compute BLEU score
        bleu_scores.append(bleu)
    return np.mean(bleu_scores)

# Compute BLEU scores
rnn_bleu = calculate_bleu_sacrebleu(rnn_translations, actual_translations)
lstm_bleu = calculate_bleu_sacrebleu(lstm_translations, actual_translations)

# Display BLEU Scores
display(Markdown("### Model BLEU Scores"))
display(Markdown(f"RNN BLEU Score: {round(rnn_bleu, 4)}"))
display(Markdown(f"LSTM BLEU Score: {round(lstm_bleu, 4)}"))
# Out:
# ### Model BLEU Scores
# RNN BLEU Score: 0.0279
# LSTM BLEU Score: 0.0

# %% [markdown]
# **Save & Export the Best Model for Inference**

# %% [markdown]
# Now that we have calculated the BLEU scores, we will:
#
# * Determine the best model (RNN or LSTM) based on BLEU score
#
# * Save the best-performing model for future use

# %% [markdown]
# **Determine the Best Model**

# %%
# Choose the best model based on BLEU Score
best_model = "RNN" if rnn_bleu > lstm_bleu else "LSTM"

display(Markdown(f"### Best Model Selected: {best_model} (Higher BLEU Score)"))
# Out:
# ### Best Model Selected: RNN (Higher BLEU Score)

# %% [markdown]
# **Save the Best Model Quietly**

# %%
import os

# Save the best model in Keras format
if best_model == "RNN":
    rnn_model.save("best_translation_rnn_model.keras")  # Use .keras format
    os.system("echo RNN Model saved as best_translation_rnn_model.keras > /dev/null")
else:
    lstm_model.save("best_translation_lstm_model.keras")  # Use .keras format
    os.system("echo LSTM Model saved as best_translation_lstm_model.keras > /dev/null")

# %% [markdown]
# **Summary**
#
#
# * RNN performed better than LSTM in this case, but the score is still very low (close to zero).
# * LSTM BLEU Score of 0.0 means the model's predictions are completely different from the actual translations.

# %% [markdown]
# **Possible Reasons for Low BLEU Scores**
#
# * Limited Dataset Size → Training was done on a small subset (5000 samples) for faster execution, leading to low accuracy.
# * Short Training Duration → Only 3 epochs were used, which is not enough for meaningful learning.
# * Vocab Limitations → The tokenizer vocabulary was capped at 5000 words, which might have removed important words.
# * Lack of Attention Mechanism → Simple RNN/LSTM models struggle with long sequences without an attention layer.

# %% [markdown]
# **Next Steps & Solutions**
#
# If we want to improve the BLEU score, we can:
#
# * Increase the Dataset Size → Train on 10,000 or more samples instead of 5,000.
# * Increase Training Epochs → Train for 10+ epochs instead of 3.
# * Use a Pretrained Model → Instead of training from scratch, use pretrained embeddings like FastText.
# * Add an Attention Mechanism → This significantly improves translation quality for sequence-to-sequence models.

# %% [markdown]
# **Milestone 1 Final Thoughts**
#
# Since this is an educational project, the goal is to showcase knowledge, not high accuracy. The current implementation successfully demonstrates:
#
# ✔ Preprocessing of text for translation
#
# ✔ Training and testing of Simple RNN & LSTM models
#
# ✔ Evaluation using BLEU Score
#
# ✔ Exporting the best model for future use

# %% [markdown]
# # **Milestone 2: Introduction**
#
# Milestone 2 focuses on advancing the **machine translation model** developed in Milestone 1 by incorporating **more sophisticated deep learning techniques**. The goal is to improve the translation quality of **English-to-German** text by implementing **various neural network architectures** and selecting the best-performing model for future deployment.
#
# **Objectives**
#
# 1. **Train RNN & LSTM models with embeddings** to improve feature learning.
# 2. **Train Bidirectional RNN & LSTM models** to capture both past and future context.
# 3. **Train Encoder-Decoder RNN & LSTM models** to implement a sequence-to-sequence architecture.
# 4. **Evaluate model performance using BLEU scores** to measure translation accuracy.
# 5. **Select and save the best-performing model** for further use.
#
# **Key Challenges & Considerations**
#
# * **Data Limitations** → The training dataset remains limited, affecting model
# generalization.
# * **Computational Constraints** → Model complexity must be balanced with execution time.
# * **Evaluation Metrics** → BLEU score is used, but translation quality could benefit from additional qualitative analysis.
#
# Milestone 2 builds upon the preprocessed data from Milestone 1 and aims to identify the most effective model for translation while keeping computational efficiency in mind.

# %% [markdown]
# **Step 1: Design, Train, and Test RNN & LSTM Model with Embeddings**
#
# In this step -
#
# * Design an RNN and LSTM model with an embedding layer.
# * Train both models on the preprocessed dataset from Milestone 1.
# * Test model performance using BLEU score.
# * Visualize training performance using accuracy and loss plots.

# %% [markdown]
# **Step 1.1: Preprocessing for Model Training**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# Reduce dataset to 5,000 samples for faster execution
sample_size = min(5000, len(translation_dataset))
translation_dataset_sample = translation_dataset.sample(sample_size, random_state=42)

# Tokenization
tokenizer = Tokenizer(num_words=5000)  # Limit vocabulary size
tokenizer.fit_on_texts(translation_dataset_sample['German'] + translation_dataset_sample['English'])

# Convert text to sequences
de_sequences = tokenizer.texts_to_sequences(translation_dataset_sample['German'])
en_sequences = tokenizer.texts_to_sequences(translation_dataset_sample['English'])

# Pad sequences
max_sequence_length = 20  # Reduce sequence length for efficiency
de_padded = pad_sequences(de_sequences, maxlen=max_sequence_length, padding='post')
en_padded = pad_sequences(en_sequences, maxlen=max_sequence_length, padding='post')

# Split dataset (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(de_padded, en_padded, test_size=0.2, random_state=42)

# Display dataset sizes
display(Markdown("### Data Prepared for Model Training"))
display(Markdown(f"- Training Set: {len(X_train)} samples"))
display(Markdown(f"- Testing Set: {len(X_test)} samples"))
# Out:
# ### Data Prepared for Model Training
# - Training Set: 4000 samples
# - Testing Set: 1000 samples

# %% [markdown]
# **Step 1.2: Define & Train RNN Model with Embeddings**

# %%
from tensorflow.keras.layers import Bidirectional

# Define improved RNN model with embedding
rnn_model = Sequential([
    Embedding(input_dim=10000, output_dim=128, input_length=max_sequence_length),
    Bidirectional(SimpleRNN(64, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dense(5000, activation='softmax')
])

# Compile the RNN model
rnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define learning rate scheduler
lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)

# Train the RNN model with 10 epochs
rnn_history = rnn_model.fit(X_train, y_train, epochs=10, batch_size=32,
                            validation_data=(X_test, y_test), callbacks=[lr_schedule])
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 62s 446ms/step - accuracy: 0.4853 - loss: 5.0808 - val_accuracy: 0.5798 - val_loss: 3.6453 - learning_rate: 0.0010
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 79s 426ms/step - accuracy: 0.5821 - loss: 3.3795 - val_accuracy: 0.5811 - val_loss: 3.8630 - learning_rate: 0.0010
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 84s 447ms/step - accuracy: 0.5841 - loss: 3.2504 - val_accuracy: 0.5822 - val_loss: 3.9476 - learning_rate: 0.0010
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 444ms/step - accuracy: 0.5854 - loss: 3.1514 - val_accuracy: 0.5825 - val_loss: 3.8020 - learning_rate: 0.0010
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 440ms/step - accuracy: 0.5850 - loss: 3.0495 - val_accuracy: 0.5831 - val_loss: 3.6648 - learning_rate: 5.0000e-04
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 53s 425ms/step - accuracy: 0.5970 - loss: 2.8729 - val_accuracy: 0.5816 - val_loss: 3.6841 - learning_rate: 5.0000e-04
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 83s 435ms/step - accuracy: 0.5917 - loss: 2.8377 - val_accuracy: 0.5808 - val_loss: 3.6911 - learning_rate: 5.0000e-04
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 80s 423ms/step - accuracy: 0.6058 - loss: 2.6487 - val_accuracy: 0.5789 - val_loss: 3.7847 - learning_rate: 2.5000e-04
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 89s 476ms/step - accuracy: 0.6045 - loss: 2.6003 - val_accuracy: 0.5803 - val_loss: 3.8361 - learning_rate: 2.5000e-04
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 53s 425ms/step - accuracy: 0.6075 - loss: 2.5356 - val_accuracy: 0.5735 - val_loss: 3.9590 - learning_rate: 2.5000e-04

# %% [markdown]
# **Step 1.3: Define & Train LSTM Model with Embeddings**

# %%
from tensorflow.keras.layers import Bidirectional

# Define improved LSTM model with embedding
lstm_model = Sequential([
    Embedding(input_dim=10000, output_dim=128, input_length=max_sequence_length),
    Bidirectional(LSTM(64, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dense(5000, activation='softmax')
])

# Compile the LSTM model
lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define learning rate scheduler
lr_schedule = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)

# Train the LSTM model with 10 epochs
lstm_history = lstm_model.fit(X_train, y_train, epochs=10, batch_size=32,
                              validation_data=(X_test, y_test), callbacks=[lr_schedule])
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 61s 450ms/step - accuracy: 0.5229 - loss: 5.0995 - val_accuracy: 0.5798 - val_loss: 3.8745 - learning_rate: 0.0010
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 79s 424ms/step - accuracy: 0.5878 - loss: 3.3711 - val_accuracy: 0.5802 - val_loss: 3.8505 - learning_rate: 0.0010
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 83s 436ms/step - accuracy: 0.5887 - loss: 3.2942 - val_accuracy: 0.5817 - val_loss: 4.0791 - learning_rate: 0.0010
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 437ms/step - accuracy: 0.5892 - loss: 3.2257 - val_accuracy: 0.5825 - val_loss: 3.7932 - learning_rate: 0.0010
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 84s 454ms/step - accuracy: 0.5953 - loss: 3.0923 - val_accuracy: 0.5838 - val_loss: 3.6872 - learning_rate: 0.0010
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 79s 433ms/step - accuracy: 0.5904 - loss: 3.0487 - val_accuracy: 0.5831 - val_loss: 3.8113 - learning_rate: 0.0010
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 84s 449ms/step - accuracy: 0.5945 - loss: 2.9428 - val_accuracy: 0.5763 - val_loss: 3.7876 - learning_rate: 0.0010
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 440ms/step - accuracy: 0.6050 - loss: 2.7887 - val_accuracy: 0.5792 - val_loss: 3.7587 - learning_rate: 0.0010
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 85s 462ms/step - accuracy: 0.5995 - loss: 2.7171 - val_accuracy: 0.5728 - val_loss: 3.8487 - learning_rate: 5.0000e-04
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 453ms/step - accuracy: 0.5999 - loss: 2.6432 - val_accuracy: 0.5697 - val_loss: 3.9412 - learning_rate: 5.0000e-04

# %% [markdown]
# **Step 1.4: Visualize Model Training Performance**

# %%
import matplotlib.pyplot as plt

# Function to plot training accuracy and loss
def plot_training(history, model_name):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Plot Accuracy
    axs[0].plot(history.history['accuracy'], label='Train Accuracy', color='blue', marker='o')
    axs[0].plot(history.history.get('val_accuracy', []), label='Validation Accuracy', color='red', marker='o')
    axs[0].set_title(f'{model_name} - Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()
    axs[0].grid(True)

    # Plot Loss
    axs[1].plot(history.history['loss'], label='Train Loss', color='blue', marker='o')
    axs[1].plot(history.history.get('val_loss', []), label='Validation Loss', color='red', marker='o')
    axs[1].set_title(f'{model_name} - Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    axs[1].grid(True)

    plt.show()

# Plot RNN Training Performance
plot_training(rnn_history, "Simple RNN")

# Plot LSTM Training Performance
plot_training(lstm_history, "LSTM")

# %% [markdown]
# **Step 1.5: Evaluate Model Performance Using BLEU Score**

# %%
import sacrebleu

# Function to compute BLEU score
def calculate_bleu_sacrebleu(predicted_texts, reference_texts):
    bleu_scores = []
    for pred, ref in zip(predicted_texts, reference_texts):
        bleu = sacrebleu.sentence_bleu(pred, [ref]).score
        bleu_scores.append(bleu)
    return np.mean(bleu_scores)

# Convert model predictions to text
def sequences_to_texts(sequences, tokenizer):
    reverse_word_index = {value: key for key, value in tokenizer.word_index.items()}
    texts = []
    for seq in sequences:
        texts.append(" ".join([reverse_word_index.get(i, "") for i in seq if i > 0]))
    return texts

# Generate predictions
rnn_pred_sequences = np.argmax(rnn_model.predict(X_test), axis=-1)
lstm_pred_sequences = np.argmax(lstm_model.predict(X_test), axis=-1)

# Convert predictions to text
rnn_translations = sequences_to_texts(rnn_pred_sequences, tokenizer)
lstm_translations = sequences_to_texts(lstm_pred_sequences, tokenizer)
actual_translations = sequences_to_texts(y_test, tokenizer)

# Compute BLEU scores
rnn_bleu = calculate_bleu_sacrebleu(rnn_translations, actual_translations)
lstm_bleu = calculate_bleu_sacrebleu(lstm_translations, actual_translations)

# Display BLEU Scores
display(Markdown("### Model BLEU Scores"))
display(Markdown(f"RNN BLEU Score: {round(rnn_bleu, 4)}"))
display(Markdown(f"LSTM BLEU Score: {round(lstm_bleu, 4)}"))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step
# ### Model BLEU Scores
# RNN BLEU Score: 2.9774
# LSTM BLEU Score: 3.1898

# %%
import sacrebleu
import numpy as np

# Function to compute BLEU score
def calculate_bleu_sacrebleu(predicted_texts, reference_texts):
    """
    Compute the BLEU score using sacreBLEU's corpus-level BLEU function.
    """
    # Ensure references are wrapped as lists of lists
    references = [[ref] for ref in reference_texts]
    return sacrebleu.corpus_bleu(predicted_texts, references).score

# Convert model predictions to text
def sequences_to_texts(sequences, tokenizer):
    """
    Convert sequences of token IDs into readable text.
    """
    reverse_word_index = {value: key for key, value in tokenizer.word_index.items()}
    texts = []

    for seq in sequences:
        words = [reverse_word_index.get(i, "[UNK]") for i in seq if i > 0]  # Handle unknown words
        texts.append(" ".join(words) if words else "[EMPTY]")  # Handle empty translations

    return texts

# Generate predictions
rnn_pred_sequences = np.argmax(rnn_model.predict(X_test), axis=-1)
lstm_pred_sequences = np.argmax(lstm_model.predict(X_test), axis=-1)

# Convert predictions to text
rnn_translations = sequences_to_texts(rnn_pred_sequences, tokenizer)
lstm_translations = sequences_to_texts(lstm_pred_sequences, tokenizer)
actual_translations = sequences_to_texts(y_test, tokenizer)

# Compute BLEU scores
rnn_bleu = calculate_bleu_sacrebleu(rnn_translations, actual_translations)
lstm_bleu = calculate_bleu_sacrebleu(lstm_translations, actual_translations)

# Display BLEU Scores
display(Markdown("### Model BLEU Scores"))
display(Markdown(f"**RNN BLEU Score:** {round(rnn_bleu, 4)}"))
display(Markdown(f"**LSTM BLEU Score:** {round(lstm_bleu, 4)}"))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step
# ### Model BLEU Scores
# **RNN BLEU Score:** 0.0
# **LSTM BLEU Score:** 21.0224

# %% [markdown]
# **Insights from RNN & LSTM Training**
#
# The LSTM model outperformed the RNN model in terms of translation quality, achieving a higher BLEU score (0.75 vs. 0.5872). Both models showed steady improvement in accuracy over five epochs, with RNN reaching 58.6% accuracy and LSTM reaching 58.2% accuracy. However, validation accuracy remained around 57%, indicating that the models may not generalize well to unseen data. The training loss decreased consistently, but validation loss plateaued, suggesting potential overfitting. The performance gap between training and validation suggests that increasing the training dataset size, fine-tuning hyperparameters, or using more advanced architectures like bidirectional models or transformer-based models could lead to better results.

# %% [markdown]
# **Step 2: Design, Train, and Test Bidirectional RNN & LSTM Models**
#
# In this step -
#
# 1. Design Bidirectional RNN and LSTM models to enhance sequence learning.
# 2. Train both models on the preprocessed dataset from Milestone 1.
# 3. Test model performance using BLEU score.
# 4. Visualize training performance using accuracy and loss plots.

# %% [markdown]
# **Step 2.1: Define & Train Bidirectional RNN Model**
#
# A **Bidirectional RNN** processes input sequences **in both forward and backward directions**, helping the model **understand the context better**.

# %%
from tensorflow.keras.layers import Bidirectional

# Define Bidirectional RNN model with embeddings
bi_rnn_model = Sequential([
    Embedding(input_dim=5000, output_dim=64, input_length=max_sequence_length),
    Bidirectional(SimpleRNN(64, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.2),
    Dense(5000, activation='softmax')
])

# Compile the model
bi_rnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
bi_rnn_history = bi_rnn_model.fit(X_train, y_train, epochs=5, batch_size=16, validation_data=(X_test, y_test))

# %% [markdown]
# **Step 2.2: Define & Train Bidirectional LSTM Model**
#
# A **Bidirectional LSTM** improves upon traditional LSTMs by allowing the model to **capture dependencies** **from both past and future words**.

# %%
# Define Bidirectional LSTM model with embeddings
bi_lstm_model = Sequential([
    Embedding(input_dim=5000, output_dim=64, input_length=max_sequence_length),
    Bidirectional(LSTM(64, return_sequences=True)),
    BatchNormalization(),
    Dropout(0.2),
    Dense(5000, activation='softmax')
])

# Compile the model
bi_lstm_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
bi_lstm_history = bi_lstm_model.fit(X_train, y_train, epochs=5, batch_size=16, validation_data=(X_test, y_test))

# %% [markdown]
# **Step 2.3: Visualize Model Training Performance**

# %%
# Function to plot training accuracy and loss
def plot_training(history, model_name):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Plot Accuracy
    axs[0].plot(history.history['accuracy'], label='Train Accuracy', color='blue')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
    axs[0].set_title(f'{model_name} - Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    # Plot Loss
    axs[1].plot(history.history['loss'], label='Train Loss', color='blue')
    axs[1].plot(history.history['val_loss'], label='Validation Loss', color='red')
    axs[1].set_title(f'{model_name} - Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

# Plot Bidirectional RNN Training Performance
plot_training(bi_rnn_history, "Bidirectional RNN")

# Plot Bidirectional LSTM Training Performance
plot_training(bi_lstm_history, "Bidirectional LSTM")

# %% [markdown]
# **Step 2.4: Evaluate Model Performance Using BLEU Score**

# %%
import sacrebleu

# Generate predictions
bi_rnn_pred_sequences = np.argmax(bi_rnn_model.predict(X_test), axis=-1)
bi_lstm_pred_sequences = np.argmax(bi_lstm_model.predict(X_test), axis=-1)

# Convert predictions to text
bi_rnn_translations = sequences_to_texts(bi_rnn_pred_sequences, tokenizer)
bi_lstm_translations = sequences_to_texts(bi_lstm_pred_sequences, tokenizer)
actual_translations = sequences_to_texts(y_test, tokenizer)

# Compute BLEU scores
bi_rnn_bleu = calculate_bleu_sacrebleu(bi_rnn_translations, actual_translations)
bi_lstm_bleu = calculate_bleu_sacrebleu(bi_lstm_translations, actual_translations)

# Display BLEU Scores
display(Markdown("### Model BLEU Scores"))
display(Markdown(f"Bidirectional RNN BLEU Score: {round(bi_rnn_bleu, 4)}"))
display(Markdown(f"Bidirectional LSTM BLEU Score: {round(bi_lstm_bleu, 4)}"))

# %% [markdown]
# **Insights from Bidirectional RNN & LSTM Training and Evaluation**
#
#
# The **Bidirectional RNN model** showed a steady improvement in accuracy, reaching 59.73% by the final epoch, with a validation accuracy of 58.08%, though validation loss slightly increased, indicating potential overfitting. Similarly, the **Bidirectional LSTM model** achieved 59.03% accuracy, with a validation accuracy of 57.79%, following a similar trend of declining training loss but fluctuating validation loss. While both models performed comparably in accuracy, **the Bidirectional RNN model outperformed the Bidirectional LSTM model in BLEU score (2.2363 vs. 1.4962), indicating better translation quality**. This suggests that **capturing both forward and backward dependencies enhances learning**, but further improvements, such as hyperparameter tuning or increased training data, may be necessary to achieve more robust generalization.

# %% [markdown]
# **Step 3: Design, Train, and Test Encoder-Decoder RNN & LSTM Model**
#
# In this step -
#
# 1. Design an Encoder-Decoder Architecture for translation.
# 2. Train both RNN and LSTM-based Encoder-Decoder models.
# 3. Evaluate BLEU Score performance.
# 4. Provide different types of visualizations for better insights.

# %% [markdown]
# **Step 3.1: Define Encoder-Decoder RNN Model**
#
#
# In the **Encoder-Decoder architecture**, the **encoder** processes the input sequence and generates a context vector that summarizes the entire sentence. The **decoder** then generates the translated output based on this context.

# %%
from tensorflow.keras.layers import Input, GRU
from tensorflow.keras.models import Model

# Define the encoder
encoder_inputs = Input(shape=(max_sequence_length,))
encoder_embedding = Embedding(input_dim=5000, output_dim=64)(encoder_inputs)
encoder_rnn = SimpleRNN(64, return_state=True)
encoder_outputs, encoder_state = encoder_rnn(encoder_embedding)

# Define the decoder
decoder_inputs = Input(shape=(max_sequence_length,))
decoder_embedding = Embedding(input_dim=5000, output_dim=64)(decoder_inputs)
decoder_rnn = SimpleRNN(64, return_sequences=True)
decoder_outputs = decoder_rnn(decoder_embedding, initial_state=encoder_state)
decoder_dense = Dense(5000, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
rnn_encoder_decoder_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
rnn_encoder_decoder_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
rnn_enc_dec_history = rnn_encoder_decoder_model.fit([X_train, X_train], y_train, epochs=5, batch_size=16, validation_data=([X_test, X_test], y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6d296bb21bcc> in <cell line: 0>()
#       3
#       4 # Define the encoder
# ----> 5 encoder_inputs = Input(shape=(max_sequence_length,))
#       6 encoder_embedding = Embedding(input_dim=5000, output_dim=64)(encoder_inputs)
#       7 encoder_rnn = SimpleRNN(64, return_state=True)
#
# NameError: name 'max_sequence_length' is not defined

# %% [markdown]
# **Step 3.2: Define Encoder-Decoder LSTM Model**
#
# The **LSTM-based Encoder-Decoder model** follows the same approach but uses **LSTM layers **instead of RNNs for better long-term dependency learning.

# %%
from tensorflow.keras.layers import LSTM

# Define the encoder
encoder_lstm = LSTM(64, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)

# Define the decoder
decoder_lstm = LSTM(64, return_sequences=True)
decoder_outputs = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
lstm_encoder_decoder_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
lstm_encoder_decoder_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# **Step 3.3: New Visualizations for Model Training Performance**
#
# Instead of accuracy/loss plots, will use:
#
# ✅ Heatmaps for loss & accuracy trends
#
# ✅ Distribution of BLEU scores across predictions

# %%
# Define the encoder
encoder_lstm = LSTM(64, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)

# Define the decoder
decoder_lstm = LSTM(64, return_sequences=True)
decoder_outputs = decoder_lstm(decoder_embedding, initial_state=[state_h, state_c])
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
lstm_encoder_decoder_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
lstm_encoder_decoder_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
lstm_enc_dec_history = lstm_encoder_decoder_model.fit(
    [X_train, X_train], y_train, epochs=5, batch_size=16, validation_data=([X_test, X_test], y_test)
)


import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Check if LSTM training history exists
if 'lstm_enc_dec_history' not in locals():
    print("Error: LSTM Encoder-Decoder training history not found. Ensure the model was trained before running visualization.")
else:
    # Extract accuracy and loss values
    epochs = range(1, 6)

    # Heatmap Data
    data = np.array([
        rnn_enc_dec_history.history['accuracy'],
        rnn_enc_dec_history.history['val_accuracy'],
        rnn_enc_dec_history.history['loss'],
        rnn_enc_dec_history.history['val_loss'],
        lstm_enc_dec_history.history['accuracy'],
        lstm_enc_dec_history.history['val_accuracy'],
        lstm_enc_dec_history.history['loss'],
        lstm_enc_dec_history.history['val_loss']
    ])

    # Reshape data for heatmap
    data = data.reshape(8, 5)

    # Define heatmap labels
    heatmap_labels = [
        "RNN Accuracy", "RNN Val Accuracy",
        "RNN Loss", "RNN Val Loss",
        "LSTM Accuracy", "LSTM Val Accuracy",
        "LSTM Loss", "LSTM Val Loss"
    ]

    # Plot heatmap
    plt.figure(figsize=(10, 6))
    sns.heatmap(data, annot=True, cmap="coolwarm", xticklabels=epochs, yticklabels=heatmap_labels)
    plt.title("Training Performance Heatmap")
    plt.xlabel("Epochs")
    plt.ylabel("Metrics")
    plt.show()

# %% [markdown]
# **Step 3.4: Evaluate Model Performance Using BLEU Score**

# %%
# Generate predictions
rnn_enc_dec_pred_sequences = np.argmax(rnn_encoder_decoder_model.predict([X_test, X_test]), axis=-1)
lstm_enc_dec_pred_sequences = np.argmax(lstm_encoder_decoder_model.predict([X_test, X_test]), axis=-1)

# Convert predictions to text
rnn_enc_dec_translations = sequences_to_texts(rnn_enc_dec_pred_sequences, tokenizer)
lstm_enc_dec_translations = sequences_to_texts(lstm_enc_dec_pred_sequences, tokenizer)
actual_translations = sequences_to_texts(y_test, tokenizer)

# Compute BLEU scores
rnn_enc_dec_bleu = calculate_bleu_sacrebleu(rnn_enc_dec_translations, actual_translations)
lstm_enc_dec_bleu = calculate_bleu_sacrebleu(lstm_enc_dec_translations, actual_translations)

# Display BLEU Scores
display(Markdown("### Model BLEU Scores"))
display(Markdown(f"Encoder-Decoder RNN BLEU Score: {round(rnn_enc_dec_bleu, 4)}"))
display(Markdown(f"Encoder-Decoder LSTM BLEU Score: {round(lstm_enc_dec_bleu, 4)}"))

# %% [markdown]
# **Step 3.5: BLEU Score Distribution Visualization**
#
# Plot the distribution of BLEU scores to understand how well the models performed across different translations.

# %%
# Collect BLEU scores for each translation
rnn_bleu_scores = [sacrebleu.sentence_bleu(pred, [ref]).score for pred, ref in zip(rnn_enc_dec_translations, actual_translations)]
lstm_bleu_scores = [sacrebleu.sentence_bleu(pred, [ref]).score for pred, ref in zip(lstm_enc_dec_translations, actual_translations)]

# Plot BLEU score distribution
plt.figure(figsize=(10, 5))
sns.kdeplot(rnn_bleu_scores, label="RNN BLEU Score Distribution", fill=True, color="blue")
sns.kdeplot(lstm_bleu_scores, label="LSTM BLEU Score Distribution", fill=True, color="red")
plt.title("BLEU Score Distribution for Encoder-Decoder Models")
plt.xlabel("BLEU Score")
plt.ylabel("Density")
plt.legend()
plt.show()

# %% [markdown]
# **Insights from Encoder-Decoder RNN & LSTM Training and Evaluation**
#
# The **Encoder-Decoder RNN model** showed steady improvement, reaching **58.77% accuracy**, but **its validation accuracy plateaued around 57.89%**, indicating limited generalization. The **LSTM-based Encoder-Decoder model performed slightly better**, **achieving 58.75% accuracy** with a more stable training loss reduction. However, validation loss remained nearly constant for both models, suggesting potential overfitting. In **BLEU score evaluation**, **the LSTM model outperformed the RNN model (0.551 vs. 0.3462)**, confirming that **LSTM handles long-range dependencies better in translation task**s. Despite improvements, further optimization is needed to enhance translation quality and generalization.

# %% [markdown]
# **Step 4: Choose the Best Performing Model and Save It**
#
# In this step -
#
# 1. Compare BLEU scores across all trained models.
# 2. Select the best-performing model based on translation quality.
# 3. Save the model using Pickle for future inference.

# %% [markdown]
# Step 4.1: Compare Model Performance

# %%
# Store BLEU scores for comparison
bleu_scores = {
    "Simple RNN": rnn_bleu,
    "Simple LSTM": lstm_bleu,
    "Bidirectional RNN": bi_rnn_bleu,
    "Bidirectional LSTM": bi_lstm_bleu,
    "Encoder-Decoder RNN": rnn_enc_dec_bleu,
    "Encoder-Decoder LSTM": lstm_enc_dec_bleu
}

# Identify the best-performing model
best_model_name = max(bleu_scores, key=bleu_scores.get)
best_bleu_score = bleu_scores[best_model_name]

# Print best model details
display(Markdown(f"### ✅ Best Model Selected: {best_model_name}"))
display(Markdown(f"**BLEU Score:** {round(best_bleu_score, 4)}"))

# %% [markdown]
# **Step 4.2: Save the Best Model**

# %%
import pickle

# Dictionary of models
models = {
    "Simple RNN": rnn_model,
    "Simple LSTM": lstm_model,
    "Bidirectional RNN": bi_rnn_model,
    "Bidirectional LSTM": bi_lstm_model,
    "Encoder-Decoder RNN": rnn_encoder_decoder_model,
    "Encoder-Decoder LSTM": lstm_encoder_decoder_model
}

# Retrieve the best model
best_model = models[best_model_name]

# Save the best model using Pickle
with open(f"best_translation_model.pkl", "wb") as file:
    pickle.dump(best_model, file)

display(Markdown(f"✅ Best Model `{best_model_name}` saved as `best_translation_model.pkl`."))

# %% [markdown]
# **Step 4.3: Verify Model Saving**

# %%
# Load the saved model
with open("best_translation_model.pkl", "rb") as file:
    loaded_model = pickle.load(file)

# Verify that the model loads correctly
print("✅ Model successfully loaded!")
print(f"Loaded Model Type: {type(loaded_model)}")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# BLEU scores from previous evaluations
bleu_scores = {
    "Simple RNN": 0.5872,
    "Simple LSTM": 0.75,
    "Bidirectional RNN": 2.2363,
    "Bidirectional LSTM": 1.4962,
    "Encoder-Decoder RNN": 0.3462,
    "Encoder-Decoder LSTM": 0.551
}

# Sort models based on BLEU score for better visualization
sorted_bleu_scores = dict(sorted(bleu_scores.items(), key=lambda item: item[1], reverse=True))

# Set color palette for visualization
sns.set_palette("coolwarm")

# Create figure for BLEU score comparison
plt.figure(figsize=(12, 6))
sns.barplot(x=list(sorted_bleu_scores.values()), y=list(sorted_bleu_scores.keys()), orient="h", palette="coolwarm")
plt.xlabel("BLEU Score", fontsize=14, fontweight="bold", color="darkblue")
plt.ylabel("Model", fontsize=14, fontweight="bold", color="darkblue")
plt.title("Comparison of BLEU Scores Across Models", fontsize=16, fontweight="bold", color="darkred")

# Annotate BLEU scores on bars
for index, value in enumerate(sorted_bleu_scores.values()):
    plt.text(value + 0.02, index, f"{value:.3f}", color="black", va="center", fontsize=12, fontweight="bold")

# Show visualization
plt.show()

# %% [markdown]
# Step 5: Final Report

# %% [markdown]
# **Final Conclusion**
#
# The project successfully implemented **multiple machine translation models** using **RNN, LSTM, Bidirectional, and Encoder-Decoder architectures**. Through rigorous **training, evaluation, and visualization**, we observed that the **Bidirectional RNN model outperformed all others with a BLEU score of 2.236**, demonstrating its superior ability to capture sequential dependencies for translation. **The Bidirectional LSTM model followed closely**, while **Encoder-Decoder models underperformed**, likely due to the limited dataset and lack of attention mechanisms.
#
# Despite these achievements, the models still show room for improvement. **Future enhancements could include**:
#
# 1. Incorporating Attention Mechanisms (such as Bahdanau or Luong Attention) to improve context retention.
# 2. Training on a larger, more diverse dataset to improve generalization.
# 3. Exploring Transformer-based architectures like BERT or GPT for higher accuracy in translation.
#
# Overall, this project demonstrates **the fundamental concepts of machine translation using deep learning**, successfully showcasing the impact of different architectures and their trade-offs.
